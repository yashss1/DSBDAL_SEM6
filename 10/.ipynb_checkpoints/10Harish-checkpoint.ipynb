# %%
import pandas as pd

# %%
DataFrame=pd.read_csv('Iris.csv')
DataFrame.columns =["sepal length in cm","sepal width in cm","petal length in cm","petal width in cm","class"]
DataFrame
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 0                   4.9                3.0                 1.4
# 1                   4.7                3.2                 1.3
# 2                   4.6                3.1                 1.5
# 3                   5.0                3.6                 1.4
# 4                   5.4                3.9                 1.7
# ..                  ...                ...                 ...
# 144                 6.7                3.0                 5.2
# 145                 6.3                2.5                 5.0
# 146                 6.5                3.0                 5.2
# 147                 6.2                3.4                 5.4
# 148                 5.9                3.0                 5.1
#
#      petal width in cm           class
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# ...

# %% [markdown]
# # Subset

# %%
Subset1=DataFrame[DataFrame['class']=='Iris-setosa']
Subset1
# Out:
#     sepal length in cm  sepal width in cm  petal length in cm  \
# 0                  4.9                3.0                 1.4
# 1                  4.7                3.2                 1.3
# 2                  4.6                3.1                 1.5
# 3                  5.0                3.6                 1.4
# 4                  5.4                3.9                 1.7
# 5                  4.6                3.4                 1.4
# 6                  5.0                3.4                 1.5
# 7                  4.4                2.9                 1.4
# 8                  4.9                3.1                 1.5
# 9                  5.4                3.7                 1.5
# 10                 4.8                3.4                 1.6
# 11                 4.8                3.0                 1.4
# 12                 4.3                3.0                 1.1
# 13                 5.8                4.0                 1.2
# ...

# %%
Subset2=DataFrame[DataFrame['class']=='Iris-virginica']
Subset2
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 99                  6.3                3.3                 6.0
# 100                 5.8                2.7                 5.1
# 101                 7.1                3.0                 5.9
# 102                 6.3                2.9                 5.6
# 103                 6.5                3.0                 5.8
# 104                 7.6                3.0                 6.6
# 105                 4.9                2.5                 4.5
# 106                 7.3                2.9                 6.3
# 107                 6.7                2.5                 5.8
# 108                 7.2                3.6                 6.1
# 109                 6.5                3.2                 5.1
# 110                 6.4                2.7                 5.3
# 111                 6.8                3.0                 5.5
# 112                 5.7                2.5                 5.0
# ...

# %%
Subset3=DataFrame[DataFrame['class']=='Iris-versicolor']
Subset3
# Out:
#     sepal length in cm  sepal width in cm  petal length in cm  \
# 49                 7.0                3.2                 4.7
# 50                 6.4                3.2                 4.5
# 51                 6.9                3.1                 4.9
# 52                 5.5                2.3                 4.0
# 53                 6.5                2.8                 4.6
# 54                 5.7                2.8                 4.5
# 55                 6.3                3.3                 4.7
# 56                 4.9                2.4                 3.3
# 57                 6.6                2.9                 4.6
# 58                 5.2                2.7                 3.9
# 59                 5.0                2.0                 3.5
# 60                 5.9                3.0                 4.2
# 61                 6.0                2.2                 4.0
# 62                 6.1                2.9                 4.7
# ...

# %% [markdown]
# # Merge

# %%
Merged=pd.concat([Subset1,Subset2])
Merged
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 0                   4.9                3.0                 1.4
# 1                   4.7                3.2                 1.3
# 2                   4.6                3.1                 1.5
# 3                   5.0                3.6                 1.4
# 4                   5.4                3.9                 1.7
# ..                  ...                ...                 ...
# 144                 6.7                3.0                 5.2
# 145                 6.3                2.5                 5.0
# 146                 6.5                3.0                 5.2
# 147                 6.2                3.4                 5.4
# 148                 5.9                3.0                 5.1
#
#      petal width in cm           class
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# ...

# %% [markdown]
# # Sort

# %%
Sorted=DataFrame.sort_values('petal length in cm')
Sorted
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 21                  4.6                3.6                 1.0
# 12                  4.3                3.0                 1.1
# 34                  5.0                3.2                 1.2
# 13                  5.8                4.0                 1.2
# 37                  4.4                3.0                 1.3
# ..                  ...                ...                 ...
# 130                 7.9                3.8                 6.4
# 104                 7.6                3.0                 6.6
# 121                 7.7                2.8                 6.7
# 116                 7.7                3.8                 6.7
# 117                 7.7                2.6                 6.9
#
#      petal width in cm           class
# 21                 0.2     Iris-setosa
# 12                 0.1     Iris-setosa
# 34                 0.2     Iris-setosa
# 13                 0.2     Iris-setosa
# ...

# %% [markdown]
# # Transpose

# %%
Transposed=DataFrame.T
Transposed
# Out:
#                             0            1            2            3    \
# sepal length in cm          4.9          4.7          4.6          5.0
# sepal width in cm           3.0          3.2          3.1          3.6
# petal length in cm          1.4          1.3          1.5          1.4
# petal width in cm           0.2          0.2          0.2          0.2
# class               Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
#                             4            5            6            7    \
# sepal length in cm          5.4          4.6          5.0          4.4
# sepal width in cm           3.9          3.4          3.4          2.9
# petal length in cm          1.7          1.4          1.5          1.4
# petal width in cm           0.4          0.3          0.2          0.2
# class               Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
#                             8            9    ...             139  \
# ...

# %% [markdown]
# # Melting

# %%
Melting=pd.melt(DataFrame,id_vars=['sepal length in cm','petal length in cm'],value_name='value',var_name='Metrics')
Melting
# Out:
#      sepal length in cm  petal length in cm            Metrics           value
# 0                   4.9                 1.4  sepal width in cm             3.0
# 1                   4.7                 1.3  sepal width in cm             3.2
# 2                   4.6                 1.5  sepal width in cm             3.1
# 3                   5.0                 1.4  sepal width in cm             3.6
# 4                   5.4                 1.7  sepal width in cm             3.9
# ..                  ...                 ...                ...             ...
# 442                 6.7                 5.2              class  Iris-virginica
# 443                 6.3                 5.0              class  Iris-virginica
# 444                 6.5                 5.2              class  Iris-virginica
# 445                 6.2                 5.4              class  Iris-virginica
# 446                 5.9                 5.1              class  Iris-virginica
#
# [447 rows x 4 columns]

# %% [markdown]
# # Casting

# %%
Casting=pd.pivot_table(DataFrame,index=['sepal length in cm','petal length in cm'],values=['sepal width in cm','petal width in cm'])
pd.set_option("display.max_rows", None)
Casting
# Out:
#                                        petal width in cm  sepal width in cm
# sepal length in cm petal length in cm
# 4.3                1.1                          0.100000           3.000000
# 4.4                1.3                          0.200000           3.100000
#                    1.4                          0.200000           2.900000
# 4.5                1.3                          0.300000           2.300000
# 4.6                1.0                          0.200000           3.600000
#                    1.4                          0.250000           3.300000
#                    1.5                          0.200000           3.100000
# 4.7                1.3                          0.200000           3.200000
#                    1.6                          0.200000           3.200000
# 4.8                1.4                          0.200000           3.000000
#                    1.6                          0.200000           3.250000
# ...

# %%
pd.reset_option('display.max_rows')

# %% [markdown]
# # END
